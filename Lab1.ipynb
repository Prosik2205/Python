# %%
import time
def delay_print(s):
    for c in s:
        print(c, end='')
        time.sleep(0.01)
    print('5')
print("The Elder Scrols:Ukraine")
# Out:
# The Elder Scrols:Ukraine

# %%
answers_array = []
quest_index = 0

delay_print("* Ви просинаєтесь в лісі біля впавшого дерева на якому сидить незнайомець\n Незнайомець: О, ти нарешті прокинувся, я тебе найшов з раною на голові, ти хоть щось про себе пам'ятає,як тебе звати?")
name=input("Введіть своє ім'я")     
print(name)
delay_print("Незнайомець:Добре "+ name + " ти пам'ятаєш свою расу?")
print("1.Хохол\n2.Кацап")
answer = input("Введіть відповідь:")
answers_array.append(answer)
match answer:
   case "1": 
      delay_print("Незнайомець:Я бачу ти своя людина,мене звати Степан радий познайомитись,ти пам'ятаєш що з тобою сталося?\n"+name+":Нічого не пам'ятаю\nСтепан:Нічого, я тебе відведу в селеще неподалік,може хтось поможе тобі") 
  
   case "2": 
      delay_print("*Незнайомець мовчки і швидко дістає палку і лупить вас поміж очей, так що ви знову втратили свідомість*")
# Out:
# * Ви просин
# аєтесь в лісі біля впавшого дерева на якому сидить незнайомець
#  Незнайомець: О, ти нарешті прокинувся, я тебе найшов з раною на голові, ти хоть щось про себе пам'ятає,як тебе звати?
# Dolboeb
# Незнайомець:Добре Dolboeb ти пам'ятаєш свою расу?
# 1.Хохол
# 2.Кацап
# Незнайомець:Я бачу ти своя людина,мене звати Степан радий познайомитись,ти пам'ятаєш що з тобою сталося?
# Dolboeb:Нічого не пам'ятаю
# Степан:Нічого, я тебе відведу в селеще неподалік,може хтось поможе тобі

# %%
quest_index = 1
previous_answer = answers_array[quest_index - 1]
answer_case = previous_answer
match previous_answer:
    case"1": 
     delay_print("* По дорозі в селище ви бачите зграю вовків.\n Степан:Не спіши, я пропоную їх просто обійти або чимось відволікти,що будемо робити?"),
     delay_print("1.Обійти\n2.Відволікти")
     answer = input("Введіть відповідь: ")
     answers_array.append(answer)  
    case"2": 
     delay_print("* Ви приходити до тями в темному і сирому підвалу, єдине що там є це лапочка над головою, яка постійно блимає.Неочіковна відкриваються двері і туди заходить чоловік у формі і зі зброєю")
     delay_print("Охоронець: Що ж кацапику в тебе  вибір або по доброму або по поганому, вибирай:\n"+name+":")
     delay_print("1.Я нічого не пам'ятаю,якщо ви поможете мені згадати я вам все розповім\n2.Пішов *****")
     answer = input("Введіть відповідь: ")
     answers_array.append(answer)
# Out:
# * По дорозі в селище ви бачите зграю вовків.
#  Степан:Не спіши, я пропоную їх просто обійти або чимось відволікти,що будемо робити?
# 1.Обійти
# 2.Відволікти

# %%
e_exit = False
quest_index = 2
previous_answer = answers_array[quest_index - 1]
match answer_case:
    case "1":
        match previous_answer:
            case "1":
                delay_print(
                    "*Почекавши пару хвилин ви бачите що вовки відійшли в сторону і ви тихо їх обходите і продовжуєте рух до селеще"
                )
            case "2":
                delay_print(
                    "*Степан дістає кусок сала і кидає його в кущі поруч з вовками. Вовки замітили що як летіло сало, частина з них побігла за ним, а решта замітила вас і вирішила напасти на вас\n Степаен:Вони нас замітили що будемо робити?"
                )
                delay_print("1.Почати бігти\n2.Розпочати бійку")
                answer = input("Введіть відповідь: ")
                answers_array.append(answer)
    case "2":
        match previous_answer:
            case "1":
                delay_print(
                    "Одна біда з вами, ти на диво дуже добре по нашому розмовляєш, добре я допоможу тобі але якщо я взнаю що ти збрехав, то трясця тобі"
                )
                delay_print(
                    "Вітаю!!! Ви закінчили демо-версії гри на кінцівку<<Можливо добрий кацап>>"
                )
                e_exit = True
            case "2":
                delay_print("Куля в лоб так куля в лоб")
                delay_print(
                    "Вітаю!!!Ви закінчили демо-версії гри на кінцівку<<Кацап лишається кацапом>>"
                )
                e_exit = True
# Out:
# *Степан дістає кусок сала і кидає його в кущі поруч з вовками. Вовки замітили що як летіло сало, частина з них побігла за ним, а решта замітила вас і вирішила напасти на вас
#  Степаен:Вони нас замітили що будемо робити?
# 1.Почати бігти
# 2.Розпочати бійку

# %%
if(e_exit == True): exit()
else:
  quest_index = 3
  match previous_answer:
            case"1":
                delay_print("Ось нарешті ви прибули у селище\n Степан:Усь ми і прийшли, ходімо в медпунтк, там подивляться до твоєї голови")
                delay_print("Вітаю!!!Ви закінчили демо-версії гри на кінцівку<<Без лишніх проблем>>")
            case"2":
                match answer:
                    case"1":
                            delay_print("*Ви починаєте втікати і бачите як один з них накинувся на Степана\n Степан:"+name+" поможи мені\n*Ви берету лежачу палку поруч і починаєте відбиватись\n*Вовки відступили і ви підходите до Степана і бачити розірвне горло\n Ви чуєте як на останьому дихані Степан каже вам:В рюкзаку лежить карта як пройти до селища побли...\nВи бачите що це останні його слова ,берете його рюкзак і йдете по наміченому маршруті\n")
                            delay_print("Вітаю!!!Ви закінчили демо-версії гри на кінцівку<<І знову один>>")
                    case"2":
                            delay_print("Степан швидко дістає з рюкзака сокиру і ножик\n Степан:тримай ніж і готу...\n Не встиг він договорити як підкравшився вовк заді накинувся на нього\nВи намагаєтися йому допомогти але ватажок стаї пригнув на вас і почав вчіпатись в глотку\nВи бачете як в очах починає темніти")
                            delay_print("Вітаю!!!Ви закінчили демо-версії гри на кінцівку<<Пасти смертю хоробрих>>")
# Out:
# *Ви починаєте втікати і бачите як один з них накинувся на Степана
#  Степан:Dolboebпоможи мені
# *Ви берету лежачу палку поруч і починаєте відбиватись
# *Вовки відступили і ви підходите до Степана і бачити розірвне горло
#  Ви чуєте як на останьому дихані Степан каже вам:В рюкзаку лежить карта як пройти до селища побли...
# Ви бачите що це останні його слова ,берете його рюкзак і йдете по наміченому маршруті
#
# Вітаю!!!Ви закінчили демо-версії гри на кінцівку<<І знову один>>
